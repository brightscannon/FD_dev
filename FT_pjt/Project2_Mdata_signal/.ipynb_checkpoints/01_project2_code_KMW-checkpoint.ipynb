# %%
# %%time ## 현재 사용되는 자료의 인코딩 문제로 한글표현이 잘 안됨.(패킷이 정확한 길이로 나뉘어야되서 특수한 인코딩을 사용하는듯 보임)
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#function들은 현재 같은 월의 데이터정제만 가능

#조건O
def rawToDataFrame(path_dir, from_date, to_date, cdt = []):           
    # Raw파일의 디렉토리와 mmdd날짜정보, 찾기조건을 받아서 데이터프레임으로 만들어 내보내주는 함수
    dtls = os.listdir(path_dir)
    dtls.sort() # 날짜순 나열
    all_data = []
    
#     def codes():
#         if
        
    print("===== 디렉토리 raw데이터 정보 =====\n",pd.DataFrame(dtls)[0])
    print("\n※--필터링조건 :",cdt)
    
    for d in range(int(from_date),int(to_date)+1):      #----------같은달 내에 날짜지정가능

        if len(str(d)) == 3 : date = "0"+str(d) #---날짜 전처리
        else : date = str(d)
            
        if "sise2local.ALL_CMDT."+date in dtls :       #----------해당 데이터파일이 있는경우 읽어오기
            data_path = path_dir+"sise2local.ALL_CMDT."+date #----읽어올 파일 경로 생성
            print("=== Raw데이터 변환중 :",data_path)
            
            with open(data_path, "rt", encoding='iso-8859-1') as f:
                for i in range(1000): #-------- ★ 1000으로 제한이 걸려있으나 차후 수정해야됨
                    t = f.readline()[17:]
                    print("  └───",i, "번째 정보 :", t[0:5],t[408:411],t[454:457], end=" || ")
                    if t[0:5]==cdt[0] and t[408:411]==cdt[1] and t[454:457]==cdt[2]: #★★필요한 정보만 찾는 구문
                        product_code = t[18:30]
                        print('product_code = ',product_code)
                        break  #★★★★★★일단 1번째자료만 로딩하기로 되어있음.
                s = f.readlines()
                
            #1.조건에 충족하는 틱정보만 골라내기
            #2.index별로 자료분리
            #순서 : 날짜, 체결시각, 현재가격, 체결수량, 매도1호가, 매수1호가, 최종매도매수, 총잔량매도, 총잔량매수
            #위의 2단계를 한방에 정리해서 시간단축(list comprehension구문임)
            ls1 = [[date,row[:17],int(row[40:48]),int(row[48:54]),row[243:251],row[161:169],row[152:153],row[235:242],row[153:160]]
                   for row in s if (product_code == row[22:34]) and (row[17:22] == 'G7016')]
#             ls.apply(code)
            for row in ls1: #-----각 파일별 데이터 순차합산
                all_data.append(row)
            
                   
    result = pd.DataFrame(all_data,columns=["날짜","체결시각","현재가격","체결수량","매도1호가","매수1호가","최종매도매수","총잔량매도","총잔량매수"])        
    return result


#조건 data_code
def rawToDataFrameALL(path_dir, from_date, to_date, data_code):
    #기간정보만 주고 그 날짜안의 모든 데이터를 순차적으로 데이터프레임화한다.
    dtls = os.listdir(path_dir)
    dtls.sort() # 날짜순 나열
    result = pd.DataFrame(columns=["date","time","raw"])
    
    print("===== 디렉토리 raw데이터 정보 =====\n",pd.DataFrame(dtls)[0])
    print("\n※--필터링조건 : 없음")
    
    for d in range(int(from_date),int(to_date)+1):           #----같은달 내에 날짜지정가능

        if len(str(d)) == 3 : date = "0"+str(d)              #----날짜 전처리
        else : date = str(d)
            
        if "sise2local.ALL_CMDT."+date in dtls :             #----해당 데이터파일이 있는경우 읽어오기
            data_path = path_dir+"sise2local.ALL_CMDT."+date #----읽어올 파일 경로 생성
            print("=== Raw데이터 변환중 :",data_path)
            
            with open(data_path, "rt", encoding='iso-8859-1') as f:
                s = f.readlines()
            print("  └─── Data loaded! Now Stacking.... ", end ="")
            
            s2 = [[date, raw[:17], raw[17:]]for raw in s if raw[17:22] == data_code]
            
            temp = pd.DataFrame(s2,columns=["date","time","raw"])
            result = result.append(temp, ignore_index=True)
            print("Complete!!") 
            
    return result


def rawSortByValues(raw, *args): #----args에 찾는종목나열
    
#     def func(date,time,d):
#         if d[:5] in args:
#             code = d[:5]
#             if code == 'G7016': #순서 : 날짜, 체결시각, 현재가격, 체결수량, 매도1호가, 매수1호가, 최종매도매수, 총잔량매도, 총잔량매수
#                 new.loc[len(new)] = {"date":date, "time":time, "itemcode":d[:5],"nowprice":int(d[23:31]),"dealamt":int(d[31:37]),"sell_1":int(d[226:234]),"buy_1":int(d[144:152]),"fin_b/s":int(d[135:136]),"remain_sell":int(d[218:225]),"remain_buy":int(d[136:143])}
#                 print(new.loc[len(new)-1])
# #             elif code == 'A3016':
# #             elif code == 'B6016':
# #             elif code == 'H1016':

#     raw.apply(lambda x:func(x['date'],x['time'],x['raw']),axis = 1) # 심각하게 오래걸림...
    
#     ls = [[date,row[:17],int(row[40:48]),int(row[48:54]),row[243:251],row[161:169],row[152:153],row[235:242],row[153:160]]
#           for row in raw if (product_code == row[22:34]) and (row[17:22] == 'G7016')]
    product_code = args[1]
    print(product_code)
    product_ID = args[0]
    print(product_ID)

#     ls1 = [[row[0],row[1],row[2][:5],int(row[2][23:31]),int(row[2][31:37]),row[2][226:234],row[2][144:152],row[2][135:136],row[2][218:225],row[2][136:143]]
#            for row in raw if (product_code == row[2][5:17]) and (product_ID == row[2][:5])]
    ls1 = [[row.loc['date'] for row in raw]]
#     new = pd.DataFrame(ls1,columns=["date","time","itemcode","nowprice","dealamt","sell_1","buy_1","fin_b/s","remain_sell","remain_buy"])
    new = pd.DataFrame(ls1,columns=["date"])
    return new
    

s=[]

#raw파일 디렉토리 경로
path_dir = "D:/FinanceData_raw/raw_data_set/"

# %%
# 조건 : DATA정보구분, 기초자산ID, 결제월번호 || (리스트형태로 다중입력 가능하도록 할 예정)
cond = ['A0016','BM3','001']                
result = rawToDataFrame(path_dir, "0213", "0213", cond)
result
# Out:
# ===== 디렉토리 raw데이터 정보 =====
#  0     sise2local.ALL_CMDT.0201
# 1     sise2local.ALL_CMDT.0202
# 2     sise2local.ALL_CMDT.0205
# 3     sise2local.ALL_CMDT.0206
# 4     sise2local.ALL_CMDT.0207
# 5     sise2local.ALL_CMDT.0208
# 6     sise2local.ALL_CMDT.0209
# 7     sise2local.ALL_CMDT.0212
# 8     sise2local.ALL_CMDT.0213
# 9     sise2local.ALL_CMDT.0214
# 10    sise2local.ALL_CMDT.0219
# 11    sise2local.ALL_CMDT.0220
# 12    sise2local.ALL_CMDT.0221
# 13    sise2local.ALL_CMDT.0222
# 14    sise2local.ALL_CMDT.0223
#
# [1786 rows x 9 columns]

# %%
#1. 여러파일 받아서 합병데이터세트 만들고
#2. 기본 코드와 아이디 분류된 데이터프레임 생성

result = rawToDataFrameALL(path_dir, "0201", "0202", "A0016")
result["data_code"] = ''
result["product_code"] = ''
result["product_ID"] = ''
result["cont_Mth"] = ''

for i in range(len(result)):
    if result["raw"][i][:5] == "A0016":
        result["data_code"][i] = "A0016"
        result["product_code"][i] = result['raw'][i][18:30]
        result["product_ID"][i] = result['raw'][i][408:411]
        result["cont_Mth"][i] = result['raw'][i][454:457]

result
# Out:
# ===== 디렉토리 raw데이터 정보 =====
#  0     sise2local.ALL_CMDT.0201
# 1     sise2local.ALL_CMDT.0202
# 2     sise2local.ALL_CMDT.0205
# 3     sise2local.ALL_CMDT.0206
# 4     sise2local.ALL_CMDT.0207
# 5     sise2local.ALL_CMDT.0208
# 6     sise2local.ALL_CMDT.0209
# 7     sise2local.ALL_CMDT.0212
# 8     sise2local.ALL_CMDT.0213
# 9     sise2local.ALL_CMDT.0214
# 10    sise2local.ALL_CMDT.0219
# 11    sise2local.ALL_CMDT.0220
# 12    sise2local.ALL_CMDT.0221
# 13    sise2local.ALL_CMDT.0222
# 14    sise2local.ALL_CMDT.0223
# 15    sise2local.ALL_CMDT.0226
# 16    sise2local.ALL_CMDT.0227
# 17    sise2local.ALL_CMDT.0228
# Name: 0, dtype: object
#
# ※--필터링조건 : 없음
# === Raw데이터 변환중 : D:/FinanceData_raw/raw_data_set/sise2local.ALL_CMDT.0201
#   └─── Data loaded! Now Stacking.... Complete!!
# === Raw데이터 변환중 : D:/FinanceData_raw/raw_data_set/sise2local.ALL_CMDT.0202
#   └─── Data loaded! Now Stacking.... Complete!!
#       date               time  \
# 0     0201  [06:34:43-307991]
# 1     0201  [06:34:43-408571]
# 2     0201  [06:34:43-509030]
# 3     0201  [06:34:43-609319]
# 4     0201  [06:34:43-709597]
# 5     0201  [06:34:43-809851]
# 6     0201  [06:34:43-910231]
# 7     0201  [06:34:44-010553]
# 8     0201  [06:34:44-110924]
# 9     0201  [06:34:44-211287]
# 10    0201  [06:34:44-311536]
# 11    0201  [06:34:44-411846]
# 12    0201  [06:34:44-512198]
# 13    0201  [06:34:44-612551]
# 14    0201  [06:34:44-712808]
# 15    0201  [06:34:44-813201]
# 16    0201  [06:34:44-913470]
# 17    0201  [06:34:45-013776]
# 18    0201  [06:34:45-114108]
# 19    0201  [06:34:45-214453]
# 20    0201  [06:34:45-314780]
# 21    0201  [06:34:45-415656]
# 22    0201  [06:34:45-516072]
# 23    0201  [06:34:45-616484]
# 24    0201  [06:34:45-716799]
# 25    0201  [06:34:45-817115]
# 26    0201  [06:34:45-917531]
# 27    0201  [06:34:46-017862]
# 28    0201  [06:34:46-118139]
# 29    0201  [06:34:46-218474]
# ...    ...                ...
# 2980  0202  [08:30:30-673342]
# 2981  0202  [08:30:30-773395]
# 2982  0202  [08:30:30-873385]
# 2983  0202  [08:30:30-973422]
# 2984  0202  [08:30:31-073465]
# 19    KR4478N2N5S8        CNH      001
# 20    KR4478N2N6S6        CNH      001
# 21    KR4478N2N7S4        CNH      001
# 22    KR4478N2N9S0        CNH      001
# 23    KR4478N2NCS7        CNH      001
# 24    KR4177N20003        EUR      001
# 25    KR4177N30002        EUR      002
# 26    KR4177N40001        EUR      003
# 27    KR4177N50000        EUR      004
# 28    KR4177N60009        EUR      005
# 29    KR4177N70008        EUR      006
# ...            ...        ...      ...
# 2980  KR4775N6N200        USD      005
# 2981  KR4775N6R102        USD      005
# 2982  KR4775N6R201        USD      005
# 2983  KR4775N6S100        USD      005
# 2984  KR4775N6S209        USD      005
# 2985  KR4775N6T108        USD      005
# 2986  KR4775N6T207        USD      005
# 2987  KR4775N6V104        USD      005
# 2988  KR4775N6V203        USD      005
# 2989  KR4775N6W102        USD      005
# 2990  KR4775N6W201        USD      005
# 2991  KR4775N72104        USD      006
# 2992  KR4775N72203        USD      006
# 2993  KR4775N73102        USD      006
# 2994  KR4775N73201        USD      006
# 2995  KR4775N74100        USD      006
# 2996  KR4775N74209        USD      006
# 2997  KR4775N75107        USD      006
# 2998  KR4775N75206        USD      006
# 2999  KR4775N76105        USD      006
# 3000  KR4775N76204        USD      006
# 3001  KR4775N79109        USD      006
# 3002  KR4775N79208        USD      006
# 3003  KR4775N7A106        USD      006
# 3004  KR4775N7A205        USD      006
# 3005  KR4775N7B104        USD      006
# 3006  KR4775N7B203        USD      006
# 3007  KR4775N7C102        USD      006
# 3008  KR4775N7C201        USD      006
# 3009  999999999999        000      000
#
# [3010 rows x 7 columns]

# %%
#3. BM3자산의 최근월물(001)찾기

dtBM3 = pd.DataFrame(columns=["date","time","raw","data_code","product_code","product_ID","cont_Mth"])

for i in range(len(result)):
    if result['product_ID'][i] == 'BM3' and  result["cont_Mth"][i] == '001':
        dtBM3.loc[len(dtBM3)] = result.loc[i] 

dtBM3
# Out:
#     date               time  \
# 0   0201  [06:34:43-307991]
# 1   0201  [06:34:43-509030]
# 2   0201  [07:00:04-346439]
# 3   0201  [07:00:04-546499]
# 4   0201  [07:30:04-365179]
# 5   0201  [07:30:04-565330]
# 6   0201  [07:50:03-452310]
# 7   0201  [07:50:03-652307]
# 8   0201  [08:30:03-599449]
# 9   0201  [08:30:03-799460]
# 10  0202  [06:34:44-475704]
# 11  0202  [06:34:44-676568]
# 12  0202  [07:00:04-022429]
# 13  0202  [07:00:04-222484]
# 14  0202  [07:30:03-966276]
# 15  0202  [07:30:04-166399]
# 16  0202  [07:50:04-280847]
# 17  0202  [07:50:04-481002]
# 18  0202  [08:30:03-659916]
# 19  0202  [08:30:03-859985]
#
#                                                   raw data_code  product_code  \
# 0   A00160030120180201KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 1   A00160030120180201KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 2   A00160030120180201KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 3   A00160030120180201KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 4   A00160030120180201KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 5   A00160030120180201KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 6   A00160030120180201KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 7   A00160030120180201KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 8   A00160030120180201KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 9   A00160030120180201KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 10  A00160029920180202KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 11  A00160029920180202KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 12  A00160029920180202KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 13  A00160029920180202KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 14  A00160029920180202KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 15  A00160029920180202KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 16  A00160029920180202KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 17  A00160029920180202KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
# 18  A00160029920180202KR4165N30007000001KRDRVFUBM3...     A0016  KR4165N30007
# 19  A00160029920180202KR4465N3N6S2000003KRDRVFUBM3...     A0016  KR4465N3N6S2
#
#    product_ID cont_Mth
# 0         BM3      001
# 1         BM3      001
# 2         BM3      001
# 3         BM3      001
# 4         BM3      001
# 5         BM3      001
# 6         BM3      001
# 7         BM3      001
# 8         BM3      001
# 9         BM3      001
# 10        BM3      001
# 11        BM3      001
# 12        BM3      001
# 13        BM3      001
# 14        BM3      001
# 15        BM3      001
# 16        BM3      001
# 17        BM3      001
# 18        BM3      001
# 19        BM3      001

# %%
# 4.product_code의 종류갯수 파악하기

product_code_set = dtBM3['product_code'].unique()
product_code_set
# Out:
# array(['KR4165N30007', 'KR4465N3N6S2'], dtype=object)

# %%
# H1016의 투자자데이터 로딩
row = rawToDataFrameALL(path_dir, "0201", "0202", "H1016")
row
# Out:
# ===== 디렉토리 raw데이터 정보 =====
#  0     sise2local.ALL_CMDT.0201
# 1     sise2local.ALL_CMDT.0202
# 2     sise2local.ALL_CMDT.0205
# 3     sise2local.ALL_CMDT.0206
# 4     sise2local.ALL_CMDT.0207
# 5     sise2local.ALL_CMDT.0208
# 6     sise2local.ALL_CMDT.0209
# 7     sise2local.ALL_CMDT.0212
# 8     sise2local.ALL_CMDT.0213
# 9     sise2local.ALL_CMDT.0214
# 10    sise2local.ALL_CMDT.0219
# 11    sise2local.ALL_CMDT.0220
# 12    sise2local.ALL_CMDT.0221
# 13    sise2local.ALL_CMDT.0222
# 14    sise2local.ALL_CMDT.0223
# 15    sise2local.ALL_CMDT.0226
# 16    sise2local.ALL_CMDT.0227
# 17    sise2local.ALL_CMDT.0228
# Name: 0, dtype: object
#
# ※--필터링조건 : 없음
# === Raw데이터 변환중 : D:/FinanceData_raw/raw_data_set/sise2local.ALL_CMDT.0201
#   └─── Data loaded! Now Stacking.... Complete!!
# === Raw데이터 변환중 : D:/FinanceData_raw/raw_data_set/sise2local.ALL_CMDT.0202
#   └─── Data loaded! Now Stacking.... Complete!!
#         date               time  \
# 0       0201  [07:30:11-083744]
# 1       0201  [07:30:11-090919]
# 2       0201  [07:30:11-096746]
# 3       0201  [07:30:11-100064]
# 4       0201  [07:30:11-103254]
# 5       0201  [07:30:11-106686]
# 6       0201  [07:30:11-109972]
# 7       0201  [07:30:11-113388]
# 8       0201  [07:30:11-117342]
# 9       0201  [07:30:11-120000]
# 10      0201  [07:30:11-123298]
# 11      0201  [07:30:11-126685]
# 12      0201  [07:30:11-130037]
# 13      0201  [07:30:11-133421]
# 14      0201  [07:30:11-136776]
# 15      0201  [07:30:11-143353]
# 16      0201  [07:30:11-146695]
# 17      0201  [07:30:11-150014]
# 18      0201  [07:30:11-153345]
# 19      0201  [07:30:11-156617]
# 20      0201  [07:30:11-160028]
# 21      0201  [07:30:11-163262]
# 22      0201  [07:30:11-166581]
# 23      0201  [07:30:11-170064]
# 24      0201  [07:30:11-173302]
# 25      0201  [07:30:11-176712]
# 26      0201  [07:30:11-180033]
# 27      0201  [07:30:11-183339]
# 28      0201  [07:30:11-186684]
# 29      0201  [07:30:11-189987]
# ...      ...                ...
# 180370  0202  [15:49:34-207717]
# 180371  0202  [15:49:34-217833]
# 180372  0202  [15:49:34-227709]
# 180373  0202  [15:49:34-237758]
# 180374  0202  [15:49:34-247865]
# 180375  0202  [15:49:34-258224]
# 180376  0202  [15:49:34-267703]
# 180377  0202  [15:49:34-277743]
# 180378  0202  [15:49:34-287747]
# 180379  0202  [15:49:34-297760]
# 180380  0202  [15:49:34-309673]
# 180381  0202  [15:49:34-318399]
# 180382  0202  [15:49:34-328411]
# 180383  0202  [15:49:34-338453]
# 180384  0202  [15:49:34-348404]
# 180385  0202  [15:49:34-358679]
# 180386  0202  [15:49:34-368447]
# 180387  0202  [15:49:34-378301]
# 180388  0202  [15:49:34-388392]
# 180389  0202  [15:49:34-818279]
# 180390  0202  [15:49:34-824825]
# 180391  0202  [15:49:34-828161]
# 180392  0202  [15:49:34-831493]
# 180393  0202  [15:49:34-834905]
# 180394  0202  [15:49:34-841608]
# 180395  0202  [15:49:34-855025]
# 180396  0202  [15:49:34-868236]
# 180397  0202  [15:49:34-898167]
# 180398  0202  [15:49:34-914823]
# 180399  0202  [15:49:34-918109]
#
#                                                       raw
# 0       H10162018020109000000KRDRVFULHG 10000000000000...
# 1       H10162018020109000000KRDRVFULHG 20000000000000...
# 2       H10162018020109000000KRDRVFULHG 30000000000000...
# 3       H10162018020109000000KRDRVFULHG 40000000000000...
# 4       H10162018020109000000KRDRVFULHG 50000000000000...
# 5       H10162018020109000000KRDRVFULHG 60000000000000...
# 6       H10162018020109000000KRDRVFULHG 70000000000000...
# 7       H10162018020109000000KRDRVFULHG 71000000000000...
# 8       H10162018020109000000KRDRVFULHG 80000000000000...
# 9       H10162018020109000000KRDRVFULHG 90000000000000...
# 10      H10162018020109000000KRDRVFULHG 99990000000000...
# 11      H10162018020109000000KRDRVFUBM3 10000000420320...
# 12      H10162018020109000000KRDRVFUBM3 20000000005330...
# 13      H10162018020109000000KRDRVFUBM3 30000000013300...
# 14      H10162018020109000000KRDRVFUBM3 40000000118950...
# 15      H10162018020109000000KRDRVFUBM3 50000000000000...
# 16      H10162018020109000000KRDRVFUBM3 60000000004940...
# 17      H10162018020109000000KRDRVFUBM3 70000000000000...
# 18      H10162018020109000000KRDRVFUBM3 71000000003080...
# 19      H10162018020109000000KRDRVFUBM3 80000000005940...
# 20      H10162018020109000000KRDRVFUBM3 90000000195470...
# 21      H10162018020109000000KRDRVFUBM3 99990000767330...
# 22      H10162018020109000000KRDRVFUBM5 10000000000000...
# 23      H10162018020109000000KRDRVFUBM5 20000000000000...
# 24      H10162018020109000000KRDRVFUBM5 30000000000000...
# 25      H10162018020109000000KRDRVFUBM5 40000000000000...
# 26      H10162018020109000000KRDRVFUBM5 50000000000000...
# 27      H10162018020109000000KRDRVFUBM5 60000000000000...
# 28      H10162018020109000000KRDRVFUBM5 70000000000000...
# 29      H10162018020109000000KRDRVFUBM5 71000000000000...
# ...                                                   ...
# 180370  H10162018020215493001KRDRVFUUSD 40000000015520...
# 180371  H10162018020215493001KRDRVFUUSD 50000000043170...
# 180372  H10162018020215493001KRDRVFUUSD 60000000000000...
# 180373  H10162018020215493001KRDRVFUUSD 70000000000000...
# 180374  H10162018020215493001KRDRVFUUSD 71000000062790...
# 180375  H10162018020215493001KRDRVFUUSD 80000000425830...
# 180376  H10162018020215493001KRDRVFUUSD 90000001540590...
# 180377  H10162018020215493001KRDRVFUUSD 99990002893160...
# 180378  H10162018020215493001KRDRVFXUSD 10000000000000...
# 180379  H10162018020215493001KRDRVFXUSD 20000000000000...
# 180380  H10162018020215493001KRDRVFXUSD 30000000000000...
# 180381  H10162018020215493001KRDRVFXUSD 40000000000000...
# 180382  H10162018020215493001KRDRVFXUSD 50000000000000...
# 180383  H10162018020215493001KRDRVFXUSD 60000000000000...
# 180384  H10162018020215493001KRDRVFXUSD 70000000000000...
# 180385  H10162018020215493001KRDRVFXUSD 71000000000000...
# 180386  H10162018020215493001KRDRVFXUSD 80000000000000...
# 180387  H10162018020215493001KRDRVFXUSD 90000000000000...
# 180388  H10162018020215493001KRDRVFXUSD 99990000000000...
# 180389  H10162018020215493001KRDRVFUKGD 10000000000000...
# 180390  H10162018020215493001KRDRVFUKGD 20000000000000...
# 180391  H10162018020215493001KRDRVFUKGD 30000000000000...
# 180392  H10162018020215493001KRDRVFUKGD 40000000000000...
# 180393  H10162018020215493001KRDRVFUKGD 50000000000000...
# 180394  H10162018020215493001KRDRVFUKGD 60000000000000...
# 180395  H10162018020215493001KRDRVFUKGD 70000000000000...
# 180396  H10162018020215493001KRDRVFUKGD 71000000000000...
# 180397  H10162018020215493001KRDRVFUKGD 80000000000000...
# 180398  H10162018020215493001KRDRVFUKGD 90000000000000...
# 180399  H10162018020215493001KRDRVFUKGD 99990000000000...
#
# [180400 rows x 3 columns]

# %%
#2. 투자자별 매도/매수 규모 파악
total_dt = pd.DataFrame(columns=["date","inv_type","sell_vol","sell_amt","buy_vol","buy_amt"])

print("working...", end="")
# row['date'] = ''
row1['inv_type'] = ''
row1['sell_vol'] = ''
row1['sell_amt'] = ''
row1['buy_vol'] = ''
row1['buy_amt'] = ''


for i in range(len(row)):
#     row['date'] = row['date'][i]
    row1['inv_type'] = row['raw'][i][32:36]
    row1['sell_vol'] = int(row['raw'][i][45:54])
    row1['sell_amt'] = int(row['raw'][i][72:90])
    row1['buy_vol'] = int(row['raw'][i][36:45])
    row1['buy_amt'] = int(row['raw'][i][54:72])

print("dataset generated! Now summing...")



result_inv = total_dt.groupby("inv_type").agg("sum").reset_index()

print(result)
# for i in range(len(result_inv)):
# Out:
# working...

# %%
rawSortByValues(result , "G7016", "KR4165N30007") #DataFrame, productCode, productID
# Out:
# KR4165N30007
# G7016
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-02519552400c> in <module>()
# ----> 1 rawSortByValues(result , "G7016", "KR4165N30007") #DataFrame, productCode, productID
#
# <ipython-input-40-19d6a2f1e699> in rawSortByValues(raw, *args)
#     109 #     ls1 = [[row[0],row[1],row[2][:5],int(row[2][23:31]),int(row[2][31:37]),row[2][226:234],row[2][144:152],row[2][135:136],row[2][218:225],row[2][136:143]]
#     110 #            for row in raw if (product_code == row[2][5:17]) and (product_ID == row[2][:5])]
# --> 111     ls1 = [[row['date'] for row in raw]]
#     112 #     new = pd.DataFrame(ls1,columns=["date","time","itemcode","nowprice","dealamt","sell_1","buy_1","fin_b/s","remain_sell","remain_buy"])
#     113     new = pd.DataFrame(ls1,columns=["date"])
#
# <ipython-input-40-19d6a2f1e699> in <listcomp>(.0)
#     109 #     ls1 = [[row[0],row[1],row[2][:5],int(row[2][23:31]),int(row[2][31:37]),row[2][226:234],row[2][144:152],row[2][135:136],row[2][218:225],row[2][136:143]]
#     110 #            for row in raw if (product_code == row[2][5:17]) and (product_ID == row[2][:5])]
# --> 111     ls1 = [[row['date'] for row in raw]]
#     112 #     new = pd.DataFrame(ls1,columns=["date","time","itemcode","nowprice","dealamt","sell_1","buy_1","fin_b/s","remain_sell","remain_buy"])
#     113     new = pd.DataFrame(ls1,columns=["date"])
#
# TypeError: string indices must be integers

# %%
result.to_csv("project2_"+str(product_ID)+"_"+str('20180213')+"_KMW.csv", index=False)

# %% [markdown]
# ---
# # 그래프화

# %%
#체결수량 50이상만 보기
# result[result['매도1호가']!=''].reset_index()

# %%
# %matplotlib inline
#주피터노트북에서 라인 아래에 보여지도록 설정

# %config InlineBackend.figure_formats = {'png','retina'} 
#png 이미지 압축기술설정, retina 그래프 해상도 2배 높히기

#그래프 한글폰트 설정(맑은고딕)
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf",size=10,weight=True).get_name()
rc('font', family=font_name)
#음수처리
mpl.rcParams['axes.unicode_minus'] = False

# %%
#종목가격,볼륨 차트

plt.figure(figsize=(12,5))
plt.plot(result['현재가격'])
plt.title('종목가격추이')
plt.xlabel('거래틱')
plt.ylabel('종목가격')
plt.show()

plt.figure(figsize=(12,5))
plt.plot(result['체결수량'])
plt.title('거래볼륨')
plt.xlabel('거래틱')
plt.ylabel('거래량')
plt.ylim(0,1000)
plt.show()

# %%
# 코드길이재기, 코드 자르기 연습
a = '[09:03:01-204059]G7016KR4175N20007079G1 0010810000000140090301190000000000000000 00108150 00108230 00108100 0010811000054080000584893110000000000000000010003141 00108100000529 00108090000107 00108080000185 00108070000059 001080600001470002292 '
print(len(a))
b = '[09:03:01-204059]G7016KR4175N20007079G1 0010810000000140090301190000000000000000 00108150 00108230 00108100 0010811000054080000584893110000000000000000010003141 00108100000529 00108090000107 00108080000185 00108070000059 001080600001470002292 00108110000071 00108120000286 00108130000276 00108140000070 0010815000024300267002300140012000800110026100080018001600110019 00109180 00107020'
b[161:169]

# %% [markdown]
# #### 코드예제
# [09:03:01-204059]G7016KR4175N20007079G1 0010810000000140090301190000000000000000 00108150 00108230 00108100 0010811000054080000584893110000000000000000010003141 00108100000529 00108090000107 00108080000185 00108070000059 001080600001470002292 00108110000071 00108120000286 00108130000276 00108140000070 0010815000024300267002300140012000800110026100080018001600110019 00109180 00107020
